# %% [markdown]
# # **Save this file as studentid1_studentid2_lab#.ipynb**
# (Your student-id is the number shown on your student card.)
#
# E.g. if you work with 3 people, the notebook should be named:
# 12301230_3434343_1238938934_lab1.ipynb.
#
# **This will be parsed by a regexp, so please double check your filename.**
#
# Before you turn this problem in, please make sure everything runs correctly. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). Note, that **you are not allowed to use Google Colab**.
#
# **Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your names and email adresses below.**

# %%
NAME = "Florian Wolf"
NAME2 = "David Biertimpel"
NAME3 = ""
EMAIL = "flocwolf@gmail.com"
EMAIL2 = "david.biertimpel@student.uva.nl"
EMAIL3 = ""

# %% [markdown]
# # Lab 1: Linear Regression and Overfitting
#
# ### Machine Learning 1, November 2018
#
# Notes on implementation:
#
# * You should write your code and answers in this IPython Notebook: http://ipython.org/notebook.html. If you have problems, please contact your teaching assistant.
# * Please write your answers right below the questions.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * Refer to last week's lab notes, i.e. http://docs.scipy.org/doc/, if you are unsure about what function to use. There are different correct ways to implement each problem!
# * For this lab, your regression solutions should be in closed form, i.e., should not perform iterative gradient-based optimization but find the exact optimum directly.
# * use the provided test boxes to check if your answers are correct

# %%
# %pylab inline
plt.rcParams["figure.figsize"] = [20,10]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# This cell makes sure that you have all the necessary libraries installed

import sys
import platform
from importlib.util import find_spec, module_from_spec

def check_newer_version(version_inst, version_nec):
    version_inst_split = version_inst.split('.')
    version_nec_split = version_nec.split('.')
    for i in range(min(len(version_inst_split), len(version_nec_split))):
        if int(version_nec_split[i]) > int(version_inst_split[i]):
            return False
        elif int(version_nec_split[i]) < int(version_inst_split[i]):
            return True
    return True


module_list = [('jupyter', '1.0.0'), 
               ('matplotlib', '2.0.2'), 
               ('numpy', '1.13.1'), 
               ('python', '3.6.2'), 
               ('sklearn', '0.19.0'), 
               ('scipy', '0.19.1'), 
               ('nb_conda', '2.2.1')]

packages_correct = True
packages_errors = []

for module_name, version in module_list:
    if module_name == 'scikit-learn':
        module_name = 'sklearn'
    if 'python' in module_name:
        python_version = platform.python_version()
        if not check_newer_version(python_version, version):
            packages_correct = False
            error = f'Update {module_name} to version {version}. Current version is {python_version}.'
            packages_errors.append(error) 
            print(error)
    else:
        spec = find_spec(module_name)
        if spec is None:
            packages_correct = False
            error = f'Install {module_name} with version {version} or newer, it is required for this assignment!'
            packages_errors.append(error) 
            print(error)
        else:
            x = __import__(module_name)
            if hasattr(x, '__version__') and not check_newer_version(x.__version__, version):
                packages_correct = False
                error = f'Update {module_name} to version {version}. Current version is {x.__version__}.'
                packages_errors.append(error) 
                print(error)

try:
    from google.colab import drive
    packages_correct = False
    error = """Please, don't use google colab!
It will make it much more complicated for us to check your homework as it merges all the cells into one."""
    packages_errors.append(error) 
    print(error)
except:
    pass

packages_errors = '\n'.join(packages_errors)

# %%
# %pylab inline
plt.rcParams["figure.figsize"] = [20,10]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# $\newcommand{\bPhi}{\mathbf{\Phi}}$
# $\newcommand{\bx}{\mathbf{x}}$
# $\newcommand{\bw}{\mathbf{w}}$
# $\newcommand{\bt}{\mathbf{t}}$
# $\newcommand{\by}{\mathbf{y}}$
# $\newcommand{\bm}{\mathbf{m}}$
# $\newcommand{\bS}{\mathbf{S}}$
# $\newcommand{\bI}{\mathbf{I}}$
#
# ## Part 1: Polynomial Regression

# %% [markdown]
# ### 1.1. Generate periodic data (5 points)
# Write a method `gen_sine(N)` that generates toy data like in fig 1.2 of Bishop's book. The method should have a parameter $N$, and should return $N$-dimensional vectors $\bx$ and $\bt$, where $\bx$ contains evenly spaced values from 0 to (including) 2$\pi$, and the elements $t_i$ of $\bt$ are distributed according to:
#
# $$t_i \sim \mathcal{N}(\mu_i, \sigma^2)$$
#
# where $x_i$ is the $i$-th elements of $\bf{x}$, the mean $\mu_i = \sin(x_i)$ and the standard deviation $\sigma = 0.25$.

# %%
def gen_sine(n):
    x = np.linspace(0, 2*np.pi, n)
    t = np.sin(x)
    mu, sigma = 0, 0.25 # mean and standard deviation
    noise = np.random.normal(mu, sigma, n)
    t += noise
    
    return x, t

# %%
### Test your function
np.random.seed(42)
N = 10
x, t = gen_sine(N)

assert x.shape == (N,), "the shape of x is incorrect"
assert t.shape == (N,), "the shape of t is incorrect"

# %% [markdown]
# ### 1.2 Polynomial regression (10 points)
#
# Write a method `fit_polynomial(x, t, M)` that finds the maximum-likelihood solution of an _unregularized_ $M$-th order polynomial for some dataset `x`. The error function to minimize w.r.t. $\bw$ is:
#
# $E(\bw) = \frac{1}{2} (\bPhi\bw - \bt)^T(\bPhi\bw - \bt)$
#
# where $\bPhi$ is the _feature matrix_ (or _design matrix_) as explained in Bishop's book at section 3.1.1, $\bt$ is the vector of target values. Your method should return a vector $\bw$ with the maximum-likelihood parameter estimates, as well as the _feature matrix_ $\bPhi$.

# %%
def designmatrix(x, M): # it is highly recommended to write a helper function that computes Phi
    raw = np.reshape(np.repeat(x, M+1, axis=0), (x.shape[0], M+1))
    phi = np.power(raw, np.arange(M+1))
    
    return phi

def fit_polynomial(x, t, M):
    Phi = designmatrix(x, M)
    w_ml =  np.dot(np.dot(np.linalg.inv(np.dot(Phi.T, Phi)), Phi.T), t)
    
    return w_ml, Phi

# %%
### Test your function
N = 10
x = np.square((np.linspace(-1, 1, N)))
t = 0.3*x + 2.5
m = 2
w, Phi = fit_polynomial(x,t,m)

assert w.shape == (m+1,), "The shape of w is incorrect"
assert Phi.shape == (N, m+1), "The shape of Phi is incorrect"

# %% [markdown]
# ### 1.3 Plot (5 points)
# Sample a dataset with $N=10$, and fit four polynomials with $M \in (0, 2, 4, 8)$.
# For each value of $M$, plot the prediction function, along with the data and the original sine function. The resulting figure should look similar to fig 1.4 of the Bishop's book. Note that you can use matplotlib's `plt.pyplot(.)` functionality for creating grids of figures.

# %%
def polyniomal_func(x, w):
    M = w.shape[0]
    raw = np.reshape(np.repeat(x, M, axis=0), (x.shape[0], M))
    x_s = np.power(raw, np.arange(M))
    y = np.dot(w, x_s.T)
    return y

def visualize_functions(x, t, orders, plt_size):
    fig = plt.figure()
    smooth_x = np.linspace(0, 2*np.pi, 1000)
    a = sin(smooth_x)
    plt.subplots_adjust(top=2, bottom=1)
    for i, M in enumerate(orders):
        
        w_ml, Phi = fit_polynomial(x, t, M)

        b = polyniomal_func(smooth_x, w_ml)
        ax = fig.add_subplot(plt_size[0], plt_size[1], i+1)
        ax.set_title("M: " + str(orders[i]), fontweight='bold', fontsize=16)
        sine_o = ax.plot(smooth_x, a, 'y') 
        sine_appr = ax.plot(smooth_x, b, 'r')
        sample_sine = ax.scatter(x, t, c='b', marker='P')
        ax.set_xlabel('$x$', fontsize=16)
        y_ax = ax.set_ylabel('$t$', fontsize=16)
        y_ax.set_rotation(0)
        plt.legend(handles=[sine_o[0], sine_appr[0], sample_sine], labels=['Sin(x)', 'Approximation', 'Sine Samples'], prop={'size': 15})
        

    plt.show()


orders = [0, 2, 4, 8]
N = 10
x, t = gen_sine(N)
plt_size = (2, 2)

visualize_functions(x, t, orders, plt_size)

# %% [markdown]
# ### 1.4 Regularized linear regression (15 points)
#
# a) (10 points) Write a method `fit_polynomial_reg(x, t, M, lamb)` that fits a _regularized_ $M$-th order polynomial to the periodic data, as discussed in the lectures, where `lamb` is the regularization term _lambda_. (Note that 'lambda' cannot be used as a variable name in Python since it has a special meaning). The error function to minimize w.r.t. $\bw$:
#
# $E(\bw) = \frac{1}{2} (\bPhi\bw - \bt)^T(\bPhi\bw - \bt) + \frac{\lambda}{2} \mathbf{w}^T \mathbf{w}$
#
# For background, see section 3.1.4 of Bishop's book.
#
# The function should return $\bw$ and $\bPhi$.

# %%
def fit_polynomial_reg(x, t, m, lamb):
    Phi = designmatrix(x, m)
    w_ml = np.dot(np.linalg.inv(lamb * np.identity(m+1) + np.dot(Phi.T, Phi)), np.dot(Phi.T, t))

    return w_ml, Phi

# %%
### Test your function
N = 10
x = np.square((np.linspace(-1, 1, N)))
t = 0.3*x + 2.5
m = 2
lamb = 0.1
w, Phi = fit_polynomial_reg(x,t,m, lamb)

assert w.shape == (m+1,), "The shape of w is incorrect"
assert Phi.shape == (N, m+1), "The shape of w is incorrect"

# %%
def visualize_functions_regulized(x, t, m, lambdas, plt_size):
    fig = plt.figure()
    smooth_x = np.linspace(0, 2*np.pi, 1000)
    a = sin(smooth_x)
    plt.subplots_adjust(top=2, bottom=1)
    for i, lamb in enumerate(lambdas):
        
        w_ml, Phi = fit_polynomial_reg(x, t, m, lamb)

        b = polyniomal_func(smooth_x, w_ml)
        ax = fig.add_subplot(plt_size[0], plt_size[1], i+1)
        ax.set_title("Lambda: " + str(np.round(lambdas[i], 4)), fontweight='bold', fontsize=16)
        sine_o = ax.plot(smooth_x, a, 'y') 
        sine_appr = ax.plot(smooth_x, b, 'r')
        sample_sine = ax.scatter(x, t, c='b', marker='P')
        ax.set_xlabel('$x$', fontsize=16)
        y_ax = ax.set_ylabel('$t$', fontsize=16)
        y_ax.set_rotation(0)
        plt.legend(handles=[sine_o[0], sine_appr[0], sample_sine], labels=['Sin(x)', 'Approximation', 'Sine Samples'], prop={'size': 15})
        


    plt.show()

N = 10
x, t = gen_sine(N)
plt_size = (2, 2)
m = 9 

lambdas = [np.log(0.7), 0, np.log(9000), np.exp(35)]

visualize_functions_regulized(x, t, m, lambdas, plt_size)

# %% [markdown]
# b) (5 points) What changes do you notice in $\bw$ and $\bPhi$ after introducing the regularization term? Why is this happening?
#
# (Write no more than 5 lines. For example, you can consider the simple test case with $t = 0.3*x + 2.5$)

# %% [markdown]
# __Answer:__ <br>
# $\bPhi$ is not affected by the regularization term and therefore does not change.
#
# However, since the regularization term $\frac{\lambda}{2} \mathbf{w}^T \mathbf{w}$ is included as an additional penalty in the sum-of-squares error function, $\bw$ is affected. The higher the values of $\bw$, the higher is the regularization term and the higher is the ultimate error. This leads to smaller weights being preferred over larger weights, depending on the value for $\lambda$. Therefore, it can be argued that the regularization term introduces a bias-variance tradeoff controlled by $\lambda$. Small values for $\lambda$ allow a more precise adaptation to the data points with a simultaneous risk of overfitting. In contrast, high values for $\lambda$ constraint the size of the coefficients in $\bw$, which results in a less accurate fit and possible underfitting (due to higher bias).

# %% [markdown]
# ### 1.5 Model selection by cross-validation (15 points)
# Use cross-validation to find a good choice of $M$ and $\lambda$, given a dataset of $N=10$ datapoints generated with `gen_sine(10)`. You should write a function that tries (loops over) a reasonable range of choices of $M$ and $\lambda$, and returns the choice with the best cross-validation error. In this case you use $K=5$ folds.
#
# You can let $M \in (0, 1, ..., 10)$, and let $\lambda \in (e^{-10}, e^{-9}, ..., e^{0})$.
#
# a) (5 points) First of all, write a method `pred_error(x_train, x_valid, t_train, t_valid, M, lamb)` that compares the prediction of your method `fit_polynomial_reg` for a given set of parameters $M$ and $\lambda$ to `t_valid`. It should return the prediction error for a single fold.

# %%
def pred_error(x_train, x_valid, t_train, t_valid, M, reg):
    w_ml, Phi = fit_polynomial_reg(x_train, t_train, M, reg)
    prediction = polyniomal_func(x_valid, w_ml)
    return np.mean(np.power(prediction - t_valid, 2))

# %%
### Test your function
N = 10
x = np.linspace(-1, 1, N)
t = 0.3*np.square(x) + 2.5
M = 2
reg = 0.1
pred_err = pred_error(x[:-2], x[-2:], t[:-2], t[-2:], M, reg)

assert pred_err < 0.001, "pred_err is too big"

# %% [markdown]
# b) (10 points) Now write a method find_best_m_and_lamb(x, t) that finds the best values for $M$ and $\lambda$. The method should return the best $M$ and $\lambda$. To get you started, here is a method you can use to generate indices of cross-validation folds.

# %%
def kfold_indices(N, k):
    all_indices = np.arange(N,dtype=int)
    np.random.shuffle(all_indices)
    idx = [int(i) for i in np.floor(np.linspace(0,N,k+1))]
    train_folds = []
    valid_folds = []
    for fold in range(k):
        valid_indices = all_indices[idx[fold]:idx[fold+1]]
        valid_folds.append(valid_indices)
        train_folds.append(np.setdiff1d(all_indices, valid_indices))
    return train_folds, valid_folds

# %%
def find_best_m_and_lamb(x, t):
    orders = np.arange(11)
    lambdas = np.exp(np.arange(-10, 1))
    train_folds, valid_folds = kfold_indices(10, 5)
    
    results = np.zeros((orders.shape[0], lambdas.shape[0]), np.float32)
    
    for i, m in enumerate(orders):
        for j, lamb in enumerate(lambdas):
            cross_val_results = []
            for train, test in zip(train_folds, valid_folds):
                error = pred_error(x[train], x[test], t[train], t[test], m, lamb)
                cross_val_results.append(error)
            results[i, j] = np.mean(cross_val_results)

    ind_m, ind_l = np.unravel_index(np.argmin(results, axis=None), results.shape)
    
    return orders[ind_m], lambdas[ind_l]

# %%
### If you want you can write your own test here

# %% [markdown]
# ### 1.6 Why grid search? (5 points)
#
# Grid search is an commonly-used technique to tune hyper-parameters in a model.
# Considering the case described in the previous step of this assignment, running a grid search over the possible parameter values (10 possible values for both $M$ and $\lambda$), results in two nested loops exploring $10 \times 10 = 100$ different configurations for the model.
#
# a) (3 points) Why do we want to optimize by changing the two hyperparameters at the same time, and not in a sequential way? We could fix one parameter at a time and iterate over the other, resulting in only $10 + 10 = 20$ experiments!

# %% [markdown]
# __Answer:__ <br>
# This approach would work for independent hyper-parameters. In this case we could find the maximum of each parameter sequentially. In reality, hyper-parameters are most likely to be correlated. To find the optimal solution for non-independent parameters, we need to consider all possible combinations, which means $10x10$ different permutations.

# %% [markdown]
# For more complex models, the number of combinations easily explodes with the number of parameters. For example, with 5 parameters we would run $10 \times 10 \times 10 \times 10 \times 10 = 100,000$ experiments.
#
# b) (2 points) Try to think or find in literature one alternative to grid search to tune hyper-parameters more efficiently. Explain very briefly (2-3 lines max) how this method avoids the combinatorial explosion we have see in grid search.

# %% [markdown]
# __Answer:__ <br>
# A more efficient alternative to grid search is Bayesian optimization. This method builds a probabilistic model and then iterates over the hyper-parameter settings, which are more likely to have a higher value. It is a compromise between exploration and exploitation.
# Other methods with higher performance than gird search are evolutionary algorithms or gradient-based optimization.

# %% [markdown]
# ### 1.7 Plot best cross-validated fit (5 points)
#
# For some dataset with $N = 10$, plot the model with the optimal $M$ and $\lambda$ according to the cross-validation error, using the method you just wrote. In addition, the plot should show the dataset itself and the function that we try to approximate. Let the plot make clear which $M$ and $\lambda$ were found.

# %%
n=10

# The defined constum function: f(x) = x²*sin²(x)+cos²(x)
f_ = lambda x: np.power(x, 2)*np.power(sin(x), 2)+np.power(cos(x), 2)

x = np.linspace(0, 2*np.pi, n)
smooth_x = np.linspace(0, 2*np.pi, 1000)
f_y = f_(smooth_x)

t = f_(x)
mu, sigma = 0, 1
noise = np.random.normal(mu, sigma, n)
t += noise

m, lamb = find_best_m_and_lamb(x, t)
w_ml, phi = fit_polynomial_reg(x, t, m, lamb)
appr_y = polyniomal_func(smooth_x, w_ml)

fig = plt.figure(figsize=(10, 6), dpi=80)
ax = fig.add_subplot(1, 1, 1)
ax.set_title("Optimal values for $M$ and $\lambda$ ($M="+str(m)+"$, $\lambda="+str(np.round(lamb, 4))+"$)", fontweight='bold', fontsize=18)
ax.set_xlabel('$x$', fontsize=16)
y_ax = ax.set_ylabel('$t$', fontsize=16)
y_ax.set_rotation(0)

func_orig = ax.plot(smooth_x, f_y, 'y') 
appr_f = ax.plot(smooth_x, appr_y, 'r')
sample_x = ax.scatter(x, t, c='b', marker='P')

plt.legend(handles=[func_orig[0], appr_f[0], sample_x], labels=['Original function', 'Optimal approximation', 'Samples'], prop={'size': 15})

plt.show()

# %% [markdown]
# ## Part 2: Bayesian Linear (Polynomial) Regression
#
# ### 2.1 Sine 2 (5 points)
#
# Write a function `gen_sine2(N)` that behaves identically to `gen_sine(N)` except that the generated values $x_i$ are not linearly spaced, but drawn from a uniform distribution between $0$ and $2 \pi$.

# %%
def gen_sine2(n):
    x = np.random.uniform(0, 2*np.pi, n)
    
    t = np.sin(x)
    
    mu, sigma = 0, 0.25 # mean and standard deviation
    noise = np.random.normal(mu, sigma, n)
    
    t += noise
    
    return x, t

# %%
### Test your function
np.random.seed(42)
N = 10
x, t = gen_sine2(N)

assert x.shape == (N,), "the shape of x is incorrect"
assert t.shape == (N,), "the shape of t is incorrect"

# %% [markdown]
# ### 2.2 Compute Posterior (15 points)
#
# You're going to implement a Bayesian linear regression model, and fit it to the periodic data. Your regression model has a zero-mean isotropic Gaussian prior over the parameters, governed by a single (scalar) precision parameter $\alpha$, i.e.:
#
# $$p(\bw \;|\; \alpha) = \mathcal{N}(\bw \;|\; 0, \alpha^{-1} \bI)$$
#
# The covariance and mean of the posterior are given by:
#
# $$\bS_N= \left( \alpha \bI + \beta \bPhi^T \bPhi \right)^{-1} $$
# $$\bm_N = \beta\; \bS_N \bPhi^T \bt$$
#
# where $\alpha$ is the precision of the predictive distribution, and $\beta$ is the noise precision.
# See MLPR chapter 3.3 for background.
#
# Write a method `fit_polynomial_bayes(x, t, M, alpha, beta)` that returns the mean $\bm_N$ and covariance $\bS_N$ of the posterior for a $M$-th order polynomial. In addition it should return the design matrix $\bPhi$. The arguments `x`, `t` and `M` have the same meaning as in question 1.2.

# %%
def fit_polynomial_bayes(x, t, M, alpha, beta):
    Phi = designmatrix(x, M)
    S = np.linalg.inv(alpha*np.identity(M+1)+beta*(np.dot(Phi.T, Phi)))
    m = beta*(np.dot(np.dot(S, Phi.T), t))
    
    return m, S, Phi

# %%
### Test your function
N = 10
x = np.linspace(-1, 1, N)
t = 0.3*np.square(x) + 2.5
M = 2
alpha = 0.6
beta = 16
m, S, Phi = fit_polynomial_bayes(x, t, M, alpha, beta)

assert m.shape == (M+1,), "the shape of m is incorrect" 
assert S.shape == (M+1, M+1), "the shape of S is incorrect"
assert Phi.shape == (N, M+1), "the shape of Phi is incorrect"

# %% [markdown]
# ### 2.3 Prediction (10 points)
#
# The predictive distribution of Bayesian linear regression is:
#
# $$ p(t \;|\; \bx, \bt, \alpha, \beta) = \mathcal{N}(t \;|\; \bm_N^T \phi(\bx), \sigma_N^2(\bx))$$
#
# $$ \sigma_N^2 = \frac{1}{\beta} + \phi(\bx)^T \bS_N \phi(\bx) $$
#
# where $\phi(\bx)$ are the computed features for a new datapoint $\bx$, and $t$ is the predicted variable for datapoint $\bx$.
#
# Write a function that `predict_polynomial_bayes(x, m, S, beta)` that returns the predictive mean, variance and design matrix $\bPhi$ given a new datapoint `x`, posterior mean `m`, posterior variance `S` and a choice of model variance `beta`.

# %%
def predict_polynomial_bayes(x, m, S, beta):
    Phi = designmatrix(x, S.shape[0]-1)
    sigma = np.zeros((0,))
    for i in range(x.shape[0]):
        sigma = np.append(sigma, np.asarray([np.sqrt(1/beta + np.dot(np.dot(Phi[i].T, S), Phi[i]))], np.float64), axis=0)
    mean = np.dot(m.T, Phi.T)
    
    print(mean)
    print(sigma)
    print(Phi)
    
    return mean, sigma, Phi

# %%
### Test your function
np.random.seed(42)
N = 10
x = np.linspace(-1, 1, N)
m = np.random.rand(3)
S = np.random.rand(3, 3)
beta = 16
mean, sigma, Phi = predict_polynomial_bayes(x, m, S, beta)

assert mean.shape == (N,), "the shape of mean is incorrect"
assert sigma.shape == (N,), "the shape of sigma is incorrect"
assert Phi.shape == (N, m.shape[0]), "the shape of Phi is incorrect"
# Out:
# [0.15581975 0.07790681 0.07228956 0.13896801 0.27794216 0.489212
#  0.77277755 1.12863879 1.55679573 2.05724837]
# [1.58918527 1.26639227 1.03054866 0.87805957 0.81118764 0.84101682
#  0.9796812  1.23009137 1.5880258  2.04868576]
# [[ 1.         -1.          1.        ]
#  [ 1.         -0.77777778  0.60493827]
#  [ 1.         -0.55555556  0.30864198]
#  [ 1.         -0.33333333  0.11111111]
#  [ 1.         -0.11111111  0.01234568]
#  [ 1.          0.11111111  0.01234568]
#  [ 1.          0.33333333  0.11111111]
#  [ 1.          0.55555556  0.30864198]
#  [ 1.          0.77777778  0.60493827]
#  [ 1.          1.          1.        ]]

# %% [markdown]
# ### 2.4 Plot predictive distribution (10 points)
#
# a) (5 points) Generate 10 datapoints with `gen_sine2(10)`. Compute the posterior mean and covariance for a Bayesian polynomial regression model with $M=4$, $\alpha=\frac{2}{5}$ and $\beta=\frac{1}{0.25^2}$.
# Plot the Bayesian predictive distribution, where you plot (for $x$ between 0 and $2 \pi$) $t$'s predictive mean and a 1-sigma predictive variance using `plt.fill_between(..., alpha=0.1)` (the alpha argument induces transparency).
#
# Include the datapoints in your plot.

# %%
x, t = gen_sine2(10)
M = 4
alpha = 2/5
beta = 1/np.power(0.25, 2)

# fitting bayes
m, S, Phi = fit_polynomial_bayes(x, t, M, alpha, beta)

# prediction with fitted bayes
x_p = np.linspace(0, 2*np.pi, 100)
mean, sigma, Phi = predict_polynomial_bayes(x_p, m, S, beta)

fig = plt.figure(figsize=(10, 6), dpi=80)
ax = fig.add_subplot(1, 1, 1)
ax.set_title("Predictive distribution with $N=10$, $M=4$, $\\alpha=\\frac{2}{5}$ and $\\beta=\\frac{1}{25^2}$", fontweight='bold', fontsize=18)
ax.set_xlabel('$x$', fontsize=16)
y_ax = ax.set_ylabel('$t$', fontsize=16)
y_ax.set_rotation(0)

# sinus curve for comparison
x_sine = np.linspace(0, 2*np.pi, 100)
y_sine = sin(x_sine)
sin_e = ax.plot(x_sine, y_sine, 'yellow')

#plotting the original x values of gen_sine2
sin2_sample = ax.scatter(x, t, c='b', marker='P')

predict_m = ax.plot(x_p, mean, 'r')
fill_b =ax.fill_between(x_p, mean-sigma, mean+sigma, facecolor='red', alpha=0.2)

# set boundaries for proper visualization
ax.set_ylim([-2, 2])
ax.set_xlim([0, 2*np.pi])

plt.legend(['Sin(x)', 'Predictive Mean', 'Sine2 Samples', 'Predictive Variance'], prop={'size': 15})
# Out:
# [-0.4882699  -0.36839944 -0.25334287 -0.14311204 -0.03771505  0.06284371
#   0.15856359  0.24944766  0.33550274  0.41673933  0.49317171  0.56481786
#   0.63169948  0.69384203  0.75127466  0.80403026  0.85214548  0.89566064
#   0.93461983  0.96907086  0.99906526  1.02465828  1.04590892  1.0628799
#   1.07563764  1.08425233  1.08879786  1.08935186  1.08599569  1.07881441
#   1.06789685  1.05333554  1.03522673  1.01367043  0.98877035  0.96063393
#   0.92937236  0.89510053  0.85793708  0.81800435  0.77542843  0.73033914
#   0.68287002  0.63315832  0.58134506  0.52757494  0.47199642  0.41476167
#   0.35602661  0.29595086  0.23469778  0.17243447  0.10933173  0.04556411
#  -0.01869012 -0.08324896 -0.14792669 -0.21253385 -0.27687726 -0.34076002
#  -0.40398149 -0.46633729 -0.52761936 -0.58761585 -0.64611124 -0.70288623
#  -0.75771784 -0.81037934 -0.86064026 -0.90826642 -0.95301992 -0.9946591
#  -1.03293861 -1.06760935 -1.0984185  -1.12510951 -1.14742209 -1.16509226
#  -1.17785226 -1.18543065 -1.18755223 -1.1839381  -1.1743056  -1.15836837
#  -1.1358363  -1.10641558 -1.06980865 -1.02571423 -0.97382731 -0.91383916
#  -0.84543731 -0.76830557 -0.68212402 -0.58656901 -0.48131318 -0.36602542
#  -0.2403709  -0.10401107  0.04339637  0.20219741]
# [0.51270232 0.469856   0.43231424 0.39993197 0.37251897 0.34982311
#  0.3315186  0.31720395 0.30641257 0.29863528 0.29335001 0.29005197
#  0.28827846 0.28762507 0.28775299 0.28838913 0.28932136 0.29039119
#  0.29148543 0.29252796 0.2934722  0.29429445 0.29498822 0.2955594
#  0.29602236 0.2963966  0.29670411 0.29696727 0.29720707 0.29744191
#  0.29768663 0.29795189 0.29824388 0.29856425 0.29891022 0.29927494
#  0.29964795 0.3000158  0.30036269 0.30067118 0.30092297 0.30109962
#  0.30118325 0.30115722 0.30100679 0.30071964 0.30028643 0.29970121
#  0.29896182 0.29807016 0.29703248 0.29585945 0.29456629 0.29317273
#  0.29170286 0.2901849  0.28865083 0.28713586 0.2856778  0.28431619
#  0.28309135 0.28204324 0.28121018 0.2806275  0.28032613 0.28033122
#  0.28066081 0.28132467 0.28232344 0.28364795 0.28527896 0.28718721
#  0.28933387 0.29167123 0.29414384 0.29668976 0.29924215 0.30173102
#  0.30408521 0.30623458 0.30811249 0.30965865 0.31082241 0.31156669
#  0.31187275 0.31174598 0.31122295 0.31037996 0.30934331 0.30830095
#  0.30751522 0.30733512 0.30820561 0.31067015 0.31536163 0.32297754
#  0.33423879 0.34983757 0.37038622 0.39638066]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [1.00000000e+00 6.34665183e-02 4.02799894e-03 2.55643068e-04
#   1.62247755e-05]
#  [1.00000000e+00 1.26933037e-01 1.61119958e-02 2.04514455e-03
#   2.59596407e-04]
#  [1.00000000e+00 1.90399555e-01 3.62519905e-02 6.90236284e-03
#   1.31420681e-03]
#  [1.00000000e+00 2.53866073e-01 6.44479830e-02 1.63611564e-02
#   4.15354252e-03]
#  [1.00000000e+00 3.17332591e-01 1.00699973e-01 3.19553835e-02
#   1.01404847e-02]
#  [1.00000000e+00 3.80799110e-01 1.45007962e-01 5.52189027e-02
#   2.10273090e-02]
#  [1.00000000e+00 4.44265628e-01 1.97371948e-01 8.76855724e-02
#   3.89556859e-02]
#  [1.00000000e+00 5.07732146e-01 2.57791932e-01 1.30889251e-01
#   6.64566803e-02]
#  [1.00000000e+00 5.71198664e-01 3.26267914e-01 1.86363797e-01
#   1.06450752e-01]
#  [1.00000000e+00 6.34665183e-01 4.02799894e-01 2.55643068e-01
#   1.62247755e-01]
#  [1.00000000e+00 6.98131701e-01 4.87387872e-01 3.40260924e-01
#   2.37546937e-01]
#  [1.00000000e+00 7.61598219e-01 5.80031847e-01 4.41751222e-01
#   3.36436944e-01]
#  [1.00000000e+00 8.25064737e-01 6.80731821e-01 5.61647821e-01
#   4.63395812e-01]
#  [1.00000000e+00 8.88531256e-01 7.89487792e-01 7.01484579e-01
#   6.23290974e-01]
#  [1.00000000e+00 9.51997774e-01 9.06299761e-01 8.62795355e-01
#   8.21379257e-01]
#  [1.00000000e+00 1.01546429e+00 1.03116773e+00 1.04711401e+00
#   1.06330688e+00]
#  [1.00000000e+00 1.07893081e+00 1.16409169e+00 1.25597439e+00
#   1.35510947e+00]
#  [1.00000000e+00 1.14239733e+00 1.30507166e+00 1.49091037e+00
#   1.70321203e+00]
#  [1.00000000e+00 1.20586385e+00 1.45410762e+00 1.75345580e+00
#   2.11442896e+00]
#  [1.00000000e+00 1.26933037e+00 1.61119958e+00 2.04514455e+00
#   2.59596407e+00]
#  [1.00000000e+00 1.33279688e+00 1.77634753e+00 2.36751045e+00
#   3.15541056e+00]
#  [1.00000000e+00 1.39626340e+00 1.94955149e+00 2.72208739e+00
#   3.80075100e+00]
#  [1.00000000e+00 1.45972992e+00 2.13081144e+00 3.11040921e+00
#   4.54035739e+00]
#  [1.00000000e+00 1.52319644e+00 2.32012739e+00 3.53400977e+00
#   5.38299110e+00]
#  [1.00000000e+00 1.58666296e+00 2.51749934e+00 3.99442294e+00
#   6.33780291e+00]
#  [1.00000000e+00 1.65012947e+00 2.72292728e+00 4.49318257e+00
#   7.41433299e+00]
#  [1.00000000e+00 1.71359599e+00 2.93641123e+00 5.03182251e+00
#   8.62251089e+00]
#  [1.00000000e+00 1.77706251e+00 3.15795117e+00 5.61187663e+00
#   9.97265558e+00]
#  [1.00000000e+00 1.84052903e+00 3.38754711e+00 6.23487879e+00
#   1.14754754e+01]
#  [1.00000000e+00 1.90399555e+00 3.62519905e+00 6.90236284e+00
#   1.31420681e+01]
#  [1.00000000e+00 1.96746207e+00 3.87090698e+00 7.61586265e+00
#   1.49839209e+01]
#  [1.00000000e+00 2.03092858e+00 4.12467091e+00 8.37691206e+00
#   1.70129101e+01]
#  [1.00000000e+00 2.09439510e+00 4.38649084e+00 9.18704494e+00
#   1.92413019e+01]
#  [1.00000000e+00 2.15786162e+00 4.65636677e+00 1.00477952e+01
#   2.16817515e+01]
#  [1.00000000e+00 2.22132814e+00 4.93429870e+00 1.09606965e+01
#   2.43473037e+01]
#  [1.00000000e+00 2.28479466e+00 5.22028663e+00 1.19272830e+01
#   2.72513925e+01]
#  [1.00000000e+00 2.34826118e+00 5.51433055e+00 1.29490883e+01
#   3.04078414e+01]
#  [1.00000000e+00 2.41172769e+00 5.81643047e+00 1.40276464e+01
#   3.38308634e+01]
#  [1.00000000e+00 2.47519421e+00 6.12658639e+00 1.51644912e+01
#   3.75350608e+01]
#  [1.00000000e+00 2.53866073e+00 6.44479830e+00 1.63611564e+01
#   4.15354252e+01]
#  [1.00000000e+00 2.60212725e+00 6.77106622e+00 1.76191759e+01
#   4.58473377e+01]
#  [1.00000000e+00 2.66559377e+00 7.10539013e+00 1.89400836e+01
#   5.04865689e+01]
#  [1.00000000e+00 2.72906028e+00 7.44777004e+00 2.03254134e+01
#   5.54692786e+01]
#  [1.00000000e+00 2.79252680e+00 7.79820595e+00 2.17766991e+01
#   6.08120160e+01]
#  [1.00000000e+00 2.85599332e+00 8.15669785e+00 2.32954746e+01
#   6.65317199e+01]
#  [1.00000000e+00 2.91945984e+00 8.52324576e+00 2.48832737e+01
#   7.26457182e+01]
#  [1.00000000e+00 2.98292636e+00 8.89784966e+00 2.65416303e+01
#   7.91717285e+01]
#  [1.00000000e+00 3.04639288e+00 9.28050956e+00 2.82720782e+01
#   8.61278576e+01]
#  [1.00000000e+00 3.10985939e+00 9.67122545e+00 3.00761513e+01
#   9.35326018e+01]
#  [1.00000000e+00 3.17332591e+00 1.00699973e+01 3.19553835e+01
#   1.01404847e+02]
#  [1.00000000e+00 3.23679243e+00 1.04768252e+01 3.39113086e+01
#   1.09763867e+02]
#  [1.00000000e+00 3.30025895e+00 1.08917091e+01 3.59454605e+01
#   1.18629328e+02]
#  [1.00000000e+00 3.36372547e+00 1.13146490e+01 3.80593731e+01
#   1.28021282e+02]
#  [1.00000000e+00 3.42719199e+00 1.17456449e+01 4.02545801e+01
#   1.37960174e+02]
#  [1.00000000e+00 3.49065850e+00 1.21846968e+01 4.25326155e+01
#   1.48466836e+02]
#  [1.00000000e+00 3.55412502e+00 1.26318047e+01 4.48950131e+01
#   1.59562489e+02]
#  [1.00000000e+00 3.61759154e+00 1.30869686e+01 4.73433067e+01
#   1.71268746e+02]
#  [1.00000000e+00 3.68105806e+00 1.35501884e+01 4.98790303e+01
#   1.83607607e+02]
#  [1.00000000e+00 3.74452458e+00 1.40214643e+01 5.25037177e+01
#   1.96601461e+02]
#  [1.00000000e+00 3.80799110e+00 1.45007962e+01 5.52189027e+01
#   2.10273090e+02]
#  [1.00000000e+00 3.87145761e+00 1.49881841e+01 5.80261193e+01
#   2.24645661e+02]
#  [1.00000000e+00 3.93492413e+00 1.54836279e+01 6.09269012e+01
#   2.39742734e+02]
#  [1.00000000e+00 3.99839065e+00 1.59871278e+01 6.39227823e+01
#   2.55588255e+02]
#  [1.00000000e+00 4.06185717e+00 1.64986837e+01 6.70152965e+01
#   2.72206562e+02]
#  [1.00000000e+00 4.12532369e+00 1.70182955e+01 7.02059776e+01
#   2.89622382e+02]
#  [1.00000000e+00 4.18879020e+00 1.75459634e+01 7.34963595e+01
#   3.07860831e+02]
#  [1.00000000e+00 4.25225672e+00 1.80816872e+01 7.68879761e+01
#   3.26947413e+02]
#  [1.00000000e+00 4.31572324e+00 1.86254671e+01 8.03823612e+01
#   3.46908025e+02]
#  [1.00000000e+00 4.37918976e+00 1.91773030e+01 8.39810487e+01
#   3.67768948e+02]
#  [1.00000000e+00 4.44265628e+00 1.97371948e+01 8.76855724e+01
#   3.89556859e+02]
#  [1.00000000e+00 4.50612280e+00 2.03051427e+01 9.14974662e+01
#   4.12298818e+02]
#  [1.00000000e+00 4.56958931e+00 2.08811465e+01 9.54182639e+01
#   4.36022279e+02]
#  [1.00000000e+00 4.63305583e+00 2.14652063e+01 9.94494995e+01
#   4.60755084e+02]
#  [1.00000000e+00 4.69652235e+00 2.20573222e+01 1.03592707e+02
#   4.86525462e+02]
#  [1.00000000e+00 4.75998887e+00 2.26574940e+01 1.07849419e+02
#   5.13362036e+02]
#  [1.00000000e+00 4.82345539e+00 2.32657219e+01 1.12221172e+02
#   5.41293814e+02]
#  [1.00000000e+00 4.88692191e+00 2.38820057e+01 1.16709497e+02
#   5.70350197e+02]
#  [1.00000000e+00 4.95038842e+00 2.45063455e+01 1.21315929e+02
#   6.00560972e+02]
#  [1.00000000e+00 5.01385494e+00 2.51387414e+01 1.26042003e+02
#   6.31956318e+02]
#  [1.00000000e+00 5.07732146e+00 2.57791932e+01 1.30889251e+02
#   6.64566803e+02]
#  [1.00000000e+00 5.14078798e+00 2.64277010e+01 1.35859208e+02
#   6.98423382e+02]
#  [1.00000000e+00 5.20425450e+00 2.70842649e+01 1.40953407e+02
#   7.33557403e+02]
#  [1.00000000e+00 5.26772102e+00 2.77488847e+01 1.46173383e+02
#   7.70000602e+02]
#  [1.00000000e+00 5.33118753e+00 2.84215605e+01 1.51520669e+02
#   8.07785102e+02]
#  [1.00000000e+00 5.39465405e+00 2.91022923e+01 1.56996799e+02
#   8.46943419e+02]
#  [1.00000000e+00 5.45812057e+00 2.97910802e+01 1.62603307e+02
#   8.87508457e+02]
#  [1.00000000e+00 5.52158709e+00 3.04879240e+01 1.68341727e+02
#   9.29513508e+02]
#  [1.00000000e+00 5.58505361e+00 3.11928238e+01 1.74213593e+02
#   9.72992256e+02]
#  [1.00000000e+00 5.64852012e+00 3.19057796e+01 1.80220438e+02
#   1.01797877e+03]
#  [1.00000000e+00 5.71198664e+00 3.26267914e+01 1.86363797e+02
#   1.06450752e+03]
#  [1.00000000e+00 5.77545316e+00 3.33558592e+01 1.92645203e+02
#   1.11261334e+03]
#  [1.00000000e+00 5.83891968e+00 3.40929830e+01 1.99066189e+02
#   1.16233149e+03]
#  [1.00000000e+00 5.90238620e+00 3.48381628e+01 2.05628291e+02
#   1.21369759e+03]
#  [1.00000000e+00 5.96585272e+00 3.55913986e+01 2.12333042e+02
#   1.26674766e+03]
#  [1.00000000e+00 6.02931923e+00 3.63526904e+01 2.19181976e+02
#   1.32151810e+03]
#  [1.00000000e+00 6.09278575e+00 3.71220382e+01 2.26176626e+02
#   1.37804572e+03]
#  [1.00000000e+00 6.15625227e+00 3.78994420e+01 2.33318526e+02
#   1.43636771e+03]
#  [1.00000000e+00 6.21971879e+00 3.86849018e+01 2.40609211e+02
#   1.49652163e+03]
#  [1.00000000e+00 6.28318531e+00 3.94784176e+01 2.48050213e+02
#   1.55854546e+03]]

# %% [markdown]
# b) (5 points) For a second plot, draw 100 samples from the parameters' posterior distribution. Each of these samples is a certain choice of parameters for 4-th order polynomial regression.
# Display each of these 100 polynomials.

# %%
M = 4
N = 10
alpha = 2/5
beta = 1/np.power(0.25, 2)

fig = plt.figure(figsize=(10, 6), dpi=80)
ax = fig.add_subplot(1, 1, 1)
ax.set_title("100 samples of the posterior distribution with $M=4$ and $N="+str(N)+"$", fontweight='bold', fontsize=18)
ax.set_xlabel('$x$', fontsize=16)
y_ax = ax.set_ylabel('$t$', fontsize=16)
y_ax.set_rotation(0)

x, t = gen_sine2(N)
sample_x = ax.scatter(x, t, c='b', marker='P')
m, S, Phi = fit_polynomial_bayes(x, t, M, alpha, beta)
x_p = np.linspace(0, 2*np.pi, 100)

for _ in range(100):
    m_normal = np.random.multivariate_normal(m, S)
    g_y = polyniomal_func(x_p, m_normal)
    ax.plot(x_p, g_y, alpha=0.2)

# set boundaries for proper visualization
ax.set_ylim([-2, 2])
ax.set_xlim([0, 2*np.pi])

plt.legend(handles=[sample_x], labels=['Sine2 Samples'], prop={'size': 15})

# %% [markdown]
# ### 2.5 Additional questions (10 points)
#
# a) (5 points) Why is $\beta=\frac{1}{0.25^2}$ the best choice of $\beta$ in section 2.4?

# %% [markdown]
# __Answer:__ <br>
# The function `gen_sine2` in question 2.1 uses a variance of $\sigma^2=0.25^2$. Furthermore, $\beta$ is given as $\frac{1}{\sigma^2}$ as the inverse of the variance. Since $0.25^2$ is the noise we introduced in the function `gen_sine2`, this is also the optimal choise for the $\beta$ value in the Bayesian Prediction as we exactly want to model this noise.

# %% [markdown]
# b) (5 points) What problems do we face when it comes to choosing basis functions in linear models?

# %% [markdown]
# __Answer:__ <br>
# When choosing the basis function, the input data has to be taken into consideration. In general, the problem of choosing an appropriate basis function highly depends on what is known about the structure of the data. If we know only little about the data, this problem becomes increasingly hard. This holds especially for a high dimensional input space, since the basis functions need to grow exponentially with the number of dimensions (curse of dimensionality). A good example for such a dilemma is the periodic characteristic of the sinus function in the previous exercises. A polynomial basis funciton is not well suited to desribe periodic structures and will thus produce an unsatisfying model.
